# %% [markdown]
# # OPEN CV

# %% [markdown]
# ### Leer, Escribir y Mostrar una imagen

# %% [markdown]
# #### Leer una imagen

# %% [markdown]
# Comando: imread()

# %%
#importar la libreria de vision por computadora
import cv2 as cv
import matplotlib.pyplot as plt
#lectura de una imagen
img=cv.imread("img1.jpg")
# mostrar la imagen
plt.imshow(img)

# %% [markdown]
# Como se observa esta en una esca de azules debido a que esta en BGR
# entonces se debe cambiar a RGB.

# %% [markdown]
# Para mostrar la imagen en una pantalla emergente.

# %% [markdown]
# ### Modos de imread()

# %% [markdown]
# Comando para cambiar la imagen a escala de grises: cv.IMREAD_GRAYSCALE

# %%
#importar la libreria de vision por computadora
import cv2 as cv
import matplotlib.pyplot as plt
#lectura de una imagen
img=cv.imread("Imgs\img1.jpg",cv.IMREAD_GRAYSCALE)
# mostrar la imagen
plt.imshow(img, cmap="gray")

# %% [markdown]
# Comando para cambiar la imagen a color: cv.IMREAD_COLOR

# %%
#importar la libreria de vision por computadora
import cv2 as cv
import matplotlib.pyplot as plt
#lectura de una imagen
img=cv.imread("Imgs\img1.jpg",cv.IMREAD_COLOR)
# mostrar la imagen
plt.imshow(img, cmap="gray")

# %%
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# # Mostrar una imagen en una venta emergente imshow()

# %%
import cv2 as cv
#leer la imagen
img = cv.imread("Imgs/img1.jpg")
cv.imshow("Minions", img)
#cerramos la ventana
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# # Funcion para guardar la imagen en disco local.
# imwrite()

# %%
import cv2 as cv
#leer la imagen
img = cv.imread("Imgs/goku.jpg")
img_gray=cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv.imwrite("Imgs/gokugris.jpg", img_gray)
# Out:
# True

# %% [markdown]
# # Lectura y escritura de archivos de Video recomendado formatos AVI mp4

# %% [markdown]
# Reproducir un archivo de video

# %%
import numpy as np 
import cv2 as cv 


cap = cv.VideoCapture("Videos/iron.mp4")
# creamos un bucle

while(cap.isOpened()):
    
    ret,frame = cap.read()
    if ret:
        
        cv.imshow("Iron Man", frame)
        
        if(cv.waitKey(10) & 0xFF ==ord("q")):
            break

    else:
        break
cap.release()
cv.destroyAllWindows()

# %% [markdown]
# Acceder a la camara de video.

# %%
import numpy as np 
import cv2 as cv 


cap = cv.VideoCapture(0)
# creamos un bucle

while(cap.isOpened()):
    
    ret,frame = cap.read()
    if ret:
        
        cv.imshow("Camara Local", frame)
        
        if(cv.waitKey(10) & 0xFF ==ord("q")):
            break

    else:
        break
cap.release()
cv.destroyAllWindows()

# %% [markdown]
# # FUNCIONES DE DIBUJO

# %% [markdown]
# ### Dibujar linea

# %%
#la funcion cv.line()
#cv.line(img,coordenadas iniciales,coordenadasfinales,color ,grosor)
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

#crear una imagen

img=np.zeros((520,640,3),np.uint8)
# dibujamos la linea en la imagen
cv.line(img,(450,50),(450,450),(0,255,0),6)
#mostrar imagen
plt.imshow(img)

# %% [markdown]
# #### Dibujar Circulo

# %%
#la funcion cv.circle()
#paramentros (img,coordenadas centro,radio,color ,grosor)
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

#crear una imagen

img=np.zeros((520,640,3),np.uint8)
# dibujamos la linea en la imagen
cv.circle(img,(300,250),50,(255,0,0),-1)
#mostrar imagen
plt.imshow(img)

# %% [markdown]
# # DibujarRectangulo

# %%
#la funcion cv.rectangle()
#cv.line(img,coordenadas iniciales,coordenadasfinales,color ,grosor)
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

#crear una imagen

img=np.zeros((520,640,3),np.uint8)
# dibujamos la linea en la imagen
cv.rectangle(img,(50,50),(300,300),(0,2,255),5)
#mostrar imagen
plt.imshow(img)

# %% [markdown]
# ### Captura eventos desde el mouse

# %%
import cv2 as cv
clicked = False

#funcion encargad de capturar el click del mouse
def onMouse(evento, x, y,flags, param):
    #variable global
    global clicked 
    
    if(evento == cv.EVENT_LBUTTONUP):
        clicked=True
    
#creamos objeto cv.VideoCapture()
camCap = cv.VideoCapture(0)
cv.namedWindow("MyWindows")
#configuramos se envie a la funcion los eventos del mouse
cv.setMouseCallback("myWIndow",onMouse)
print("Mostrando estado de la camara, Presione en la ventana para detener")
ret,frame=camCap.read()
while(ret and cv.waitKey(1)==-1 and not clicked):
    cv.imshow("MyWindow", frame)
    ret,frame=camCap.read()
camCap.release()
cv.destroyAllWindows()
# Out:
# Mostrando estado de la camara, Presione en la ventana para detener

# %% [markdown]
# Programa para dibujar circulos en el estado del mouse.

# %%
import numpy as np
import cv2 as cv
import math
def draw_circle(event, x, y, flags, param):
    
    if(event == cv.EVENT_LBUTTONDBLCLK):
        
        cv.circle(img, (x, y), 25, (255,0,0), -1 )
        
img = np.zeros((512,512,3), np.uint8)

cv.namedWindow('Dibujando Circulos')
cv.setMouseCallback('Dibujando Circulos', draw_circle)

while(True):
    cv.imshow('Dibujando Circulos',img)
    if (cv.waitKey(1) & 0xFF ==ord('q')):
        break
    
cv.destroyAllWindows()

# %% [markdown]
# # TAREA

# %% [markdown]
# Realizar un ejercicio capturando eventos con el mouse donde se pulse el Botón izquierdo dibuje un circulo, pulsamos el botón derecho dibuja un rectángulo

# %%
import numpy as np #se importa las librerias
import cv2 as cv
def draw_circleandrectangle(event, x, y, flags, param): #creamos el evento

    
    if(event == cv.EVENT_LBUTTONDOWN):#condicional que significa si damos click izquierdo dibuja un circulo
        
       cv.circle(img, (x, y), 25, (255,200,0), -1 )
    
    if(event == cv.EVENT_RBUTTONDOWN):#condicional que significa si damos click derecho dibuja un rectangulo
       cv.rectangle(img, (x+50,y+50), (x,y),(0,255,0),-1)
       
        
img = np.zeros((512,512,3), np.uint8)# crea una ventana de 512x512

cv.namedWindow('Dibujando Circulos y Rectangulos') #identifica el nombre de la ventana
cv.setMouseCallback('Dibujando Circulos y Rectangulos', draw_circleandrectangle)#llama al evento en la ventana creada anteriormente

while(True): #condicional de que se muestre la ventana hasta que presionemos la letra x
    
    cv.imshow('Dibujando Circulos y Rectangulos',img)
    if (cv.waitKey(1) & 0xFF ==ord('x')):
        break
        
cv.destroyAllWindows()

# %% [markdown]
# # Operaciones con Imagenes

# %% [markdown]
# Acceso y Modificacion depixeles

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread("Imgs/img2.jpg")
plt.imshow(img)

# %%
#Para acceder al valor del pixel en sus 3 canaes
px=img[100,100]
px
# Out:
# array([106, 131, 105], dtype=uint8)

# %%
#accediendo al valor de un pixel en un solo canal B

px=img[100,100,0]
px
# Out:
# 106

# %%
#accediendo al valor de un pixel en un solo canal G

px=img[100,100,1]
px
# Out:
# 131

# %%
#accediendo al valor de un pixel en un solo canal R

px=img[100,100,2]
px
# Out:
# 105

# %% [markdown]
# # Modificacion

# %%
#Modificando el valo de pixeles
img[100,100]=[255,255,255]
img[100,100]
# Out:
# array([255, 255, 255], dtype=uint8)

# %% [markdown]
# # NUMPY

# %% [markdown]
# Libreria optimizada para calculos rapidos de matrices.

# %%
#extraer parte de la imagen
img2=img[:100, 150:500]
plt.imshow(img2)

# %%
#accediendo
img.item(50,50,2)
# Out:
# 117

# %%
#modificando
img.itemset((50,50,2),100)

# %%
img.item(50,50,2)
# Out:
# 100

# %% [markdown]
# Acediendo a las propiedades de la Imagen
# Las imagenes poseen propiedades como numero de fulas, numero de columnas, numero de pixeles, typo de dato.
#
# Metodo Shape

# %%
img.shape
# Out:
# (183, 275, 3)

# %% [markdown]
# Metodo dtyper

# %%
img.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# Size

# %%
#tamaño
img.size
# Out:
# 150975

# %% [markdown]
# # ROI DE UNA IMAGEN

# %% [markdown]
# SELECCIONAR PARTE DE LA IMAGEN Y COPIARLA

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

img=cv.imread("Imgs\img2.jpg")
plt.imshow(img)

# %%
#extraer la re1ion de interes
pelota = img [28:60,180:214]
plt.imshow(pelota)

# %% [markdown]
# Copiamos el roi de la imagen.

# %%
img[28:60,11:45] = pelota

plt.imshow(img)

# %% [markdown]
# DIVISION Y FUSION DE CANALES

# %% [markdown]
# split()

# %%
#nos permite dividir los canales de una imagen
b,g,r = cv.split(img)

# %%
plt.imshow(b)
plt.title("Canal Azul")
# Out:
# Text(0.5, 1.0, 'Canal Azul')

# %%
plt.imshow(g)
plt.title("Canal Verde")
# Out:
# Text(0.5, 1.0, 'Canal Verde')

# %%
plt.imshow(r)
plt.title("Canal Rojo")
# Out:
# Text(0.5, 1.0, 'Canal Rojo')

# %% [markdown]
# merge() permite unir los canales de una imagen

# %%
img_unida = cv.merge((b,g,r))
plt.imshow(img_unida)

# %%
channel_blue = img[:,:,0]
plt.imshow(channel_blue)

# %%
 img[:,:,0]=0
plt.imshow(img)

# %% [markdown]
# # Operaciones Aritmeticas con Imagenes

# %% [markdown]
# Mescla de Imagenes

# %% [markdown]
# Eso tambien es una adicion de imagen m

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

img1 = cv.imread("Imgs/mugi.png")
img2 = cv.imread("Imgs/img3.png")
#cambio de espacio de color
img1=cv.cvtColor(img1, cv.COLOR_BGR2RGB)
img2=cv.cvtColor(img2, cv.COLOR_BGR2RGB)
#IGUALAR EL TAMANO
fil,cols,chan=img1.shape
img2=cv.resize(img2,(cols,fil))

# %%
#mostramos las imagenes
plt.figure(1)
plt.imshow(img1)
plt.title("Mugiwaras")

plt.figure(2)
plt.imshow(img2)
plt.title("OpenCV")
# Out:
# Text(0.5, 1.0, 'OpenCV')

# %%
#combinar imagenes
img_out = cv.addWeighted(img1,0.7,img2, 0.3,0)
plt.imshow(img_out)

# %% [markdown]
# # Operaciones bit a bit

# %% [markdown]
# Operaciones and , or, not y xor

# %%
#immportamos las librerias
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# cargar nuestras imagenes
img1 = cv.imread('Imgs/mugi.png')
img2 = cv.imread('Imgs/img3.png')
# cambiando espacio de color
mugi = cv.cvtColor(img1, cv.COLOR_BGR2RGB)
cv2 = cv.cvtColor(img2, cv.COLOR_BGR2RGB)
# mostrado las imagenes leidas
plt.figure(1)
plt.imshow(mugi)
plt.figure(2)
plt.imshow(cv2)

# %%
#cambiamos el tamano de la imagen
fil,col,_=mugi.shape
fil2,col2,_=cv2.shape
cv2=cv.resize(cv2,(col2//2,fil))
plt.imshow(cv2)

# %%
fil, col,_ = cv2.shape
roi=img1[0:fil,0:col]
plt.imshow(roi)

# %%
# creamos una mascara del logotipo
cv2_gray=cv.cvtColor(cv2, cv.COLOR_RGB2GRAY)
ret,mask = cv.threshold(cv2_gray,150,255, cv.THRESH_BINARY)
plt.imshow(mask, cmap="gray")

# %%
#Creamos una mascara invertida
mask_inv = cv.bitwise_not(mask)
plt.imshow(mask_inv, cmap="gray")

# %%
#tomamos el rol menos la mascara
img1_bg = cv.bitwise_and(roi,roi,mask=mask)
plt.imshow(img1_bg)

# %%
#tomamos region de interes del logotipo opencv
img2_bg = cv.bitwise_and(cv2,cv2,mask=mask_inv)
plt.imshow(img2_bg)

# %%
img = img1_bg + img2_bg
plt.imshow(img)

# %%
mugi[0:fil,0:col]=img
plt.imshow(mugi)

# %% [markdown]
# ### Procesamiento de imagenes

# %% [markdown]
# Cambio de Espacio de Color de las Imagenes

# %%
#Cambio de espacio de color de las imagenes
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img=cv.imread("Imgs\img1.JPG")
img=cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img),plt.title("Imagen Original")
# Out:
# (<matplotlib.image.AxesImage at 0x1fbda3c9610>,
#  Text(0.5, 1.0, 'Imagen Original'))

# %%
plt.imshow(img[:,:,0]),plt.title("R")
# Out:
# (<matplotlib.image.AxesImage at 0x1fbda409280>, Text(0.5, 1.0, 'R'))

# %%
plt.imshow(img[:,:,1]),plt.title("G")
# Out:
# (<matplotlib.image.AxesImage at 0x1fbda43cbe0>, Text(0.5, 1.0, 'G'))

# %%
plt.imshow(img[:,:,2]),plt.title("B")
# Out:
# (<matplotlib.image.AxesImage at 0x1fbda8c1b20>, Text(0.5, 1.0, 'B'))

# %% [markdown]
# # YUV

# %% [markdown]
# La gente comenzó a pensar en diferentes métodos para separar la
# información de intensidad, de la información de color. Por lo tanto, se les ocurrió el espacio de
# color YUV. Y se refiere a la luminancia o intensidad, y los canales U / V representan información
# de color. Esto funciona bien en muchas aplicaciones porque el sistema visual humano percibe la
# información de intensidad de manera muy diferente a la información de color.

# %%
# importamos librerias
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img = cv.imread("Imgs/img1.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2YUV)
plt.imshow(img),plt.title("Imagen Original")
# Out:
# (<matplotlib.image.AxesImage at 0x1fbd89f5ca0>,
#  Text(0.5, 1.0, 'Imagen Original'))

# %%
plt.imshow(img[:,:,0]),plt.title("Luminosidad")
# Out:
# (<matplotlib.image.AxesImage at 0x1fbdaa1c250>, Text(0.5, 1.0, 'Luminosidad'))

# %%
plt.imshow(img[:,:,1]),plt.title("U")
# Out:
# (<matplotlib.image.AxesImage at 0x1fbdaa5ab20>, Text(0.5, 1.0, 'U'))

# %%
plt.imshow(img[:,:,2]),plt.title("V")
# Out:
# (<matplotlib.image.AxesImage at 0x1fbdaabf2b0>, Text(0.5, 1.0, 'V'))

# %% [markdown]
# HSV: Matiz, saturacion, valor de los colores

# %%
#Cambio de espacio de color de las imagenes
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img=cv.imread("Imgs\goku.JPG")
img=cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img),plt.title("Imagen Original")
# Out:
# (<matplotlib.image.AxesImage at 0x1fbdac380d0>,
#  Text(0.5, 1.0, 'Imagen Original'))

# %%
plt.imshow(img[:,:,0]),plt.title("Canal H")
# Out:
# (<matplotlib.image.AxesImage at 0x1fbdac906a0>, Text(0.5, 1.0, 'Canal H'))

# %%
plt.imshow(img[:,:,1]),plt.title("Canal s")
# Out:
# (<matplotlib.image.AxesImage at 0x1fbdace8b80>, Text(0.5, 1.0, 'Canal s'))

# %%
plt.imshow(img[:,:,2]),plt.title("Canal V")
# Out:
# (<matplotlib.image.AxesImage at 0x1fbdad4b2e0>, Text(0.5, 1.0, 'Canal V'))
